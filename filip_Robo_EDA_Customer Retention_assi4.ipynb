# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [raw]
# Problem Statement:
# E-retail factors for customer activation and retention: A case study from Indian e-commerce customers
#
#     Customer satisfaction has emerged as one of the most important factors that guarantee the success of online store;
# it has been posited as a key stimulant of purchase, repurchase intentions and
# customer loyalty. A comprehensive review of the literature, theories and models have been carried out to propose
# the models for customer activation and customer retention. Five major factors that contributed to the success of an
# e-commerce store have been identified as: service quality, system quality, information quality, trust and net benefit.
#     The research furthermore investigated the factors that influence the online customers repeat purchase intention.
# The combination of both utilitarian value and hedonistic values are needed to affect the repeat purchase
# intention (loyalty) positively. The data is collected from the Indian online shoppers. Results indicate the
# e-retail success factors, which are very much critical for customer satisfaction.
# Be careful: There are two sheets (one is detailed) and second is encoded in the excel file.
#     You may use any of them by extracting in separate excel sheet. The number of column(s) is more than 47.
# Read the column header carefully.
#
# Note : Data Scientists have to apply their analytical skills to give findings and conclusions in detailed data analysis written in jupyter notebook . Only data analysis is required.
# Need not to create machine learning models /but still if anybody comes with it that is welcome.

# %%
#loading Dataset
df_cust=pd.read_excel('customer_retention_dataset.xlsx',sheet_name=0)

# %%
# display first 5 records 
df_cust.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
df_cust.shape
# Out:
# (269, 71)

# %% [markdown]
# #### no. of rows : 269 , no. of columns: 71

# %%
df_cust.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df_cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %% [markdown]
# #### we can see only 1 column(pincode) is of int type and  rest of the all(70) columns are of object data type .we can see no null values present in dataset.

# %%
# find out age range
df_cust['2 How old are you? '].unique()
# Out:
# array(['31-40 years', '21-30 years', '41-50 yaers', 'Less than 20 years',
#        '51 years and above'], dtype=object)

# %% [markdown]
# #### there are 5 age ranges

# %%
df_cust['2 How old are you? '].value_counts()
# Out:
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: 2 How old are you? , dtype: int64

# %%
sns.catplot(df_cust['2 How old are you? '],data=df_cust,kind='count',height=7,aspect=2)

# %% [markdown]
# #### Age catagory31-40 years do more shoping than others  and lowest is of catagory 51 years and above

# %%
# find out age range

print(df_cust['3 Which city do you shop online from?'].nunique())
df_cust['3 Which city do you shop online from?'].unique()
# Out:
# 11
# array(['Delhi', 'Greater Noida', 'Karnal ', 'Bangalore ', 'Noida',
#        'Solan', 'Moradabad', 'Gurgaon ', 'Merrut', 'Ghaziabad',
#        'Bulandshahr'], dtype=object)

# %%
sns.catplot(df_cust['3 Which city do you shop online from?'],data=df_cust,kind='count',height=7,aspect=2)

# %% [markdown]
# #### There are total 11 cities from which people like to shop online .

# %%
df_cust['3 Which city do you shop online from?'].value_counts()
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Ghaziabad        18
# Solan            18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: 3 Which city do you shop online from?, dtype: int64

# %% [markdown]
# #### People has given highest prefrence to Delhi then Greater Noida ,Noida lowest prefrence is given to Bulandshahr

# %%
# duration from whivh people are shoping online
df_cust['6 How many times you have made an online purchase in the past 1 year?'].value_counts()
# Out:
# Less than 10 times    114
# 31-40 times            63
# 41 times and above     47
# 11-20 times            29
# 21-30 times            10
# 42 times and above      6
# Name: 6 How many times you have made an online purchase in the past 1 year?, dtype: int64

# %%
sns.catplot(df_cust['6 How many times you have made an online purchase in the past 1 year?'],data=df_cust,kind='count',height=7,aspect=2)

# %% [markdown]
# #### almost 42.3 % people have done Less than 10 times(114) shoping in last year

# %%
# getting details of internet access
df_cust['7 How do you access the internet while shopping on-line?'].value_counts()
# Out:
# Mobile internet    142
# Wi-Fi               76
# Mobile Internet     47
# Dial-up              4
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64

# %%
sns.catplot(df_cust['7 How do you access the internet while shopping on-line?'],data=df_cust,kind='count',height=7,aspect=2)

# %% [markdown]
# #### almost 53 % people use mobile internet and 28% uses Wi-Fi and rest 19% of people uses Mobile Internet and Dial-up

# %%
# getting devices used 
df_cust['8 Which device do you use to access the online shopping?'].value_counts()
# Out:
# Smartphone    141
# Laptop         86
# Desktop        30
# Tablet         12
# Name: 8 Which device do you use to access the online shopping?, dtype: int64

# %%
sns.catplot(df_cust['8 Which device do you use to access the online shopping?'],data=df_cust,kind='count',height=7,aspect=2)

# %% [markdown]
# #### 53% People uses Smartphones of shoping ,laptops 32% ,Desktop 11% ,Tablet 4%
# ####  Smartphones and laptops are most popular devices amoung people for online shoping

# %%
#### Browser used for shoping 
df_cust['11 What browser do you run on your device to access the website?\t\t\t                                                          '].value_counts()
# Out:
# Google chrome      216
# Safari              40
# Opera                8
# Mozilla Firefox      5
# Name: 11 What browser do you run on your device to access the website?\t\t\t                                                          , dtype: int64

# %%
sns.catplot(df_cust['11 What browser do you run on your device to access the website?\t\t\t                                                          '],data=df_cust,kind='count',height=7,aspect=2)

# %% [markdown]
# #### ' Google chrome' (216) is widely used browser then 'Safari' ,'Opera' and last 'Mozilla Firefox' .

# %%
# Channels from where people got know
df_cust['12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   '].value_counts()
# Out:
# Search Engine        230
# Content Marketing     20
# Display Adverts       19
# Name: 12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   , dtype: int64

# %%
sns.catplot(df_cust['12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   '],data=df_cust,kind='count',height=7,aspect=2)

# %% [markdown]
# #### 'Search Engine '(230) is the best medium to advertise for Online store here 86% people got to know form it .

# %%
df_cust['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '].value_counts()
# Out:
# more than 15 mins    123
# 6-10 mins             71
# 11-15 mins            46
# Less than 1 min       15
# 1-5 mins              14
# Name: 14 How much time do you explore the e- retail store before making a purchase decision?                                                                   , dtype: int64

# %%
sns.catplot(df_cust['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '],data=df_cust,kind='count',height=7,aspect=2)

# %% [markdown]
# **Almost 50% people would prefer to search more options before buying the product.**

# %%
# payment modes
df_cust[ '15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               '].value_counts()
# Out:
# Credit/Debit cards                    148
# Cash on delivery (CoD)                 76
# E-wallets (Paytm, Freecharge etc.)     45
# Name: 15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               , dtype: int64

# %%
sns.catplot(df_cust['15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               '],data=df_cust,kind='count',height=7,aspect=2)

# %% [markdown]
# #### Mostly People prefers card paymnet mode ,then Some uses CO too and very less goes for E-Wallets.

# %%
df_cust['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   '].value_counts()
# Out:
# Sometimes          171
# Never               48
# Frequently          35
# Very frequently     15
# Name: 16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   , dtype: int64

# %%
sns.catplot(df_cust['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   '],data=df_cust,kind='count',height=7,aspect=2)

# %% [markdown]
# **Only 23% of people will never leave the shoping trolly abandon**

# %%
df_cust['17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       '].value_counts()
# Out:
# Better alternative offer        133
# Promo code not applicable        54
# Change in price                  37
# Lack of trust                    31
# No preferred mode of payment     14
# Name: 17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       , dtype: int64

# %%
sns.catplot(df_cust['17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       '],data=df_cust,kind='count',height=7,aspect=2)

# %% [markdown]
# #### 1)If you provid ebest offer to people than anywhere else people won't leave the trolly abandon .
# #### 2) before purchasing they should get clarity whether Promo code is applicable or not .

# %%
df_cust['18 The content on the website must be easy to read and understand'].value_counts()
# Out:
# Strongly agree (5)       164
# Agree (4)                 80
# Strongly disagree (1)     18
# Indifferent (3)            7
# Name: 18 The content on the website must be easy to read and understand, dtype: int64

# %%
sns.catplot(df_cust['18 The content on the website must be easy to read and understand'],data=df_cust,kind='count',height=7,aspect=2)

# %% [markdown]
# #### Website plays important role in online shoping from where user is getting details n going to shop ,data on website should be easy to access to any layman otherwise though you have great deals if people won't able to access them they won't shop from you though they wish.

# %%
df_cust['20 Complete information on listed seller and product being offered is important for purchase decision.'].value_counts()
# Out:
# Agree (4)                101
# Strongly agree (5)        87
# Indifferent (3)           52
# Dis-agree (2)             18
# Strongly disagree (1)     11
# Name: 20 Complete information on listed seller and product being offered is important for purchase decision., dtype: int64

# %%
sns.catplot(df_cust['20 Complete information on listed seller and product being offered is important for purchase decision.'],data=df_cust,kind='count',height=7,aspect=2)

# %% [markdown]
# #### It is very important ot provide seller and product info To gain customer's trust .

# %%
df_cust['21 All relevant information on listed products must be stated clearly'].value_counts()
# Out:
# Agree (4)                132
# Strongly agree (5)       107
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Name: 21 All relevant information on listed products must be stated clearly, dtype: int64

# %%
sns.catplot(df_cust['21 All relevant information on listed products must be stated clearly'],data=df_cust,kind='count',height=7,aspect=2)

# %% [markdown]
# #### From the above statistics we can almost 95% people want to have clarity in product information .

# %%
df_cust['22 Ease of navigation in website'].value_counts()
# Out:
# Strongly agree (5)       141
# Agree (4)                105
# Strongly disagree (1)     18
# Dis-agree (2)              5
# Name: 22 Ease of navigation in website, dtype: int64

# %%
sns.catplot(df_cust['22 Ease of navigation in website'],data=df_cust,kind='count',height=7,aspect=2)

# %%
df_cust['23 Loading and processing speed'].value_counts()
# Out:
# Strongly agree (5)       115
# Agree (4)                112
# Dis-agree (2)             18
# Strongly disagree (1)     12
# Indifferent (3)           12
# Name: 23 Loading and processing speed, dtype: int64

# %%
sns.catplot(df_cust['23 Loading and processing speed'],data=df_cust,kind='count',height=7,aspect=2)

# %% [markdown]
# #### Server response speed, layout, CSS and JS optimization should be in such way that people will get quick response,if loading time is high there are very high chances of loosing customers.

# %%
df_cust['24 User friendly Interface of the website'].value_counts()
# Out:
# Strongly agree (5)       189
# Agree (4)                 45
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Indifferent (3)            5
# Name: 24 User friendly Interface of the website, dtype: int64

# %%
sns.catplot(df_cust['24 User friendly Interface of the website'],data=df_cust,kind='count',height=7,aspect=2)

# %%
df_cust['25 Convenient Payment methods'].value_counts()
# Out:
# Strongly agree (5)    159
# Agree (4)              80
# Dis-agree (2)          30
# Name: 25 Convenient Payment methods, dtype: int64

# %%
sns.catplot(df_cust['25 Convenient Payment methods'],data=df_cust,kind='count',height=7,aspect=2)

# %% [markdown]
# #### All possible payment options will highly retain customers .

# %%
df_cust['26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'].value_counts()
# Out:
# Strongly agree (5)    141
# Agree (4)              86
# Disagree (2)           30
# indifferent  (3)       12
# Name: 26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time, dtype: int64

# %%
sns.catplot(df_cust['26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'],data=df_cust,kind='count',height=7,aspect=2)

# %% [markdown]
# #### Timelines should be followed by stores inturn customers trust will be gained.

# %%
df_cust['27 Empathy (readiness to assist with queries) towards the customers'].value_counts()
# Out:
# Strongly agree (5)       194
# Agree (4)                 42
# Strongly disagree (1)     18
# indifferent (3)           15
# Name: 27 Empathy (readiness to assist with queries) towards the customers, dtype: int64

# %%
sns.catplot(df_cust['27 Empathy (readiness to assist with queries) towards the customers'],data=df_cust,kind='count',height=7,aspect=2)

# %% [markdown]
# #### Customer care or Chatbots should be well trained to handle customer queries

# %%
df_cust['28 Being able to guarantee the privacy of the customer'].value_counts()
# Out:
# Strongly agree (5)    185
# Agree (4)              58
# indifferent (3)        26
# Name: 28 Being able to guarantee the privacy of the customer, dtype: int64

# %%
sns.catplot(df_cust['28 Being able to guarantee the privacy of the customer'],data=df_cust,kind='count',height=7,aspect=2)

# %% [markdown]
# #### Customer data should be secure ,which increases customers trust on store.

# %%
df_cust['29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)'].value_counts()
# Out:
# Strongly agree (5)       149
# Agree (4)                 94
# indifferent (3)           15
# Strongly disagree (1)     11
# Name: 29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.), dtype: int64

# %%
sns.catplot(df_cust['29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)'],data=df_cust,kind='count',height=7,aspect=2)

# %% [markdown]
# #### customer should be able to easily contact to the store in caes of any query ,for that eevry store should provide all possible ways on coomunication.

# %%
df_cust['30 Online shopping gives monetary benefit and discounts'].value_counts()
# Out:
# Strongly agree (5)       105
# Agree (4)                 85
# indifferent (3)           50
# Strongly disagree (1)     18
# Dis-agree (2)             11
# Name: 30 Online shopping gives monetary benefit and discounts, dtype: int64

# %%
sns.catplot(df_cust['30 Online shopping gives monetary benefit and discounts'],data=df_cust,kind='count',height=7,aspect=2)

# %% [markdown]
# #### Along with the cost price customer will compaire products on the basis of other monetary benefits which they are getting.

# %%
df_cust['31 Enjoyment is derived from shopping online'].value_counts()
# Out:
# Strongly agree (5)       86
# indifferent (3)          75
# Agree (4)                59
# Strongly disagree (1)    30
# Dis-agree (2)            19
# Name: 31 Enjoyment is derived from shopping online, dtype: int64

# %%
sns.catplot(df_cust['31 Enjoyment is derived from shopping online'],data=df_cust,kind='count',height=7,aspect=2)

# %% [markdown]
# #### Shoping on store should give happiness not the stress by late delivery,by providing faulty or low quality products etc..

# %%
df_cust['32 Shopping online is convenient and flexible'].value_counts()
# Out:
# Strongly agree (5)    146
# Agree (4)              78
# indifferent (3)        33
# Dis-agree (2)          12
# Name: 32 Shopping online is convenient and flexible, dtype: int64

# %%
sns.catplot(df_cust['32 Shopping online is convenient and flexible'],data=df_cust,kind='count',height=7,aspect=2)

# %% [markdown]
# #### sittting at your place you are shoping returning products so thats why its highly opted by people now a days.

# %%
df_cust['33 Return and replacement policy of the e-tailer is important for purchase decision'].value_counts()
type(df_cust['33 Return and replacement policy of the e-tailer is important for purchase decision'])
# Out:
# pandas.core.series.Series

# %%
sns.catplot(df_cust['33 Return and replacement policy of the e-tailer is important for purchase decision'],data=df_cust,kind='count')

# %% [markdown]
# #### Almost 93% people will purchase product with stores who have easy  Return and replacement policies.

# %%
df_cust['34 Gaining access to loyalty programs is a benefit of shopping online'].value_counts()
# Out:
# Strongly agree (5)       115
# Agree (4)                 64
# indifferent (3)           64
# Dis-agree (2)             15
# Strongly disagree (1)     11
# Name: 34 Gaining access to loyalty programs is a benefit of shopping online, dtype: int64

# %%
sns.catplot(df_cust['34 Gaining access to loyalty programs is a benefit of shopping online'],data=df_cust,kind='count',height=7,aspect=1.5)

# %% [markdown]
# #### loyalty programs is a benefits this is Directly propornate retention .66%agree with it

# %%
df_cust['35 Displaying quality Information on the website improves satisfaction of customers'].value_counts()
# Out:
# Strongly agree (5)    133
# Agree (4)              80
# indifferent (3)        56
# Name: 35 Displaying quality Information on the website improves satisfaction of customers, dtype: int64

# %%
sns.catplot(df_cust['35 Displaying quality Information on the website improves satisfaction of customers'],data=df_cust,kind='count',height=7,aspect=1)

# %% [markdown]
# #### 79% people will prefer to buy product whose quality information is diaplayed .retention is directly proportionate

# %%
df_cust['36 User derive satisfaction while shopping on a good quality website or application'].value_counts()
# Out:
# Strongly agree (5)    175
# Agree (4)              86
# Dis-agree (2)           8
# Name: 36 User derive satisfaction while shopping on a good quality website or application, dtype: int64

# %%
sns.catplot(df_cust['36 User derive satisfaction while shopping on a good quality website or application'],data=df_cust,kind='count',height=7,aspect=1)

# %% [markdown]
# #### 97% people agree if quality will be  good they would buy products online . highest direct impact on retention rate.

# %%
df_cust['37 Net Benefit derived from shopping online can lead to users satisfaction'].value_counts()
# Out:
# Strongly agree (5)    164
# Agree (4)              54
# indifferent (3)        40
# Dis-agree (2)          11
# Name: 37 Net Benefit derived from shopping online can lead to users satisfaction, dtype: int64

# %%
sns.catplot(df_cust['37 Net Benefit derived from shopping online can lead to users satisfaction'],data=df_cust,kind='count',height=7,aspect=1)

# %% [markdown]
# #### Everyone like to fix deal which will give them maximum benefit .Benifit make people happy and satisfied and plays important role in getting the product chooseed by customers.

# %%
df_cust['38 User satisfaction cannot exist without trust'].value_counts()
# Out:
# Strongly agree (5)       122
# Agree (4)                117
# Strongly disagree (1)     18
# Dis-agree (2)              7
# indifferent (3)            5
# Name: 38 User satisfaction cannot exist without trust, dtype: int64

# %%
sns.catplot(df_cust['38 User satisfaction cannot exist without trust'],data=df_cust,kind='count',height=7,aspect=2)

# %% [markdown]
# #### 89% people agree that User satisfaction cannot exist without trust .

# %%
df_cust['39 Offering a wide variety of listed product in several category'].value_counts()
# Out:
# Strongly agree (5)    111
# Agree (4)              94
# indifferent (3)        57
# Dis-agree (2)           7
# Name: 39 Offering a wide variety of listed product in several category, dtype: int64

# %%
sns.catplot(df_cust['39 Offering a wide variety of listed product in several category'],data=df_cust,kind='count',height=7,aspect=1.5)

# %% [markdown]
# #### 75% customers will be retained if they will get wide variety of products .

# %%
df_cust['40 Provision of complete and relevant product information'].value_counts()
# Out:
# Strongly agree (5)    135
# Agree (4)              98
# indifferent (3)        31
# Disagree (2)            5
# Name: 40 Provision of complete and relevant product information, dtype: int64

# %%
sns.catplot(df_cust['40 Provision of complete and relevant product information'],data=df_cust,kind='count',height=7,aspect=1)

# %% [markdown]
# #### 86.6 % people belive complete and relevant product info will retain customers.

# %%
df_cust['41 Monetary savings'].value_counts()
# Out:
# Strongly agree (5)    148
# Agree (4)              75
# Disagree (2)           31
# indifferent (3)        15
# Name: 41 Monetary savings, dtype: int64

# %%
sns.catplot(df_cust['41 Monetary savings'],data=df_cust,kind='count',height=7,aspect=1)

# %% [markdown]
# #### 83 % people belive retation depends on monetary benefits on purchase .

# %%
df_cust['42 The Convenience of patronizing the online retailer'].value_counts()
# Out:
# Agree (4)             138
# indifferent (3)        77
# Strongly agree (5)     54
# Name: 42 The Convenience of patronizing the online retailer, dtype: int64

# %%
sns.catplot(df_cust['42 The Convenience of patronizing the online retailer'],data=df_cust,kind='count',height=7,aspect=1)

# %%
df_cust['43 Shopping on the website gives you the sense of adventure'].value_counts()
# Out:
# Agree (4)                101
# indifferent (3)           59
# Strongly agree (5)        54
# Dis-agree (2)             50
# Strongly disagree (1)      5
# Name: 43 Shopping on the website gives you the sense of adventure, dtype: int64

# %%
sns.catplot(df_cust['43 Shopping on the website gives you the sense of adventure'],data=df_cust,kind='count',height=7,aspect=2)

# %% [markdown]
# #### few people likw to take adventures like to explore new things so will opt for this new way of shopping through sense of adventure.

# %%
df_cust['44 Shopping on your preferred e-tailer enhances your social status'].value_counts()
# Out:
# indifferent (3)          100
# Agree (4)                 59
# Strongly agree (5)        48
# Strongly disagree (1)     33
# Dis-agree (2)             29
# Name: 44 Shopping on your preferred e-tailer enhances your social status, dtype: int64

# %%
sns.catplot(df_cust['44 Shopping on your preferred e-tailer enhances your social status'],data=df_cust,kind='count',height=7,aspect=2)

# %% [markdown]
# #### 40% people says they buy online just for the sack of Social Status where as 23%completely disagree this and 37% have diffrent reasons to shop online

# %%
df_cust['45 You feel gratification shopping on your favorite e-tailer'].value_counts()
# Out:
# indifferent (3)          101
# Strongly agree (5)        65
# Agree (4)                 63
# Disagree (2)              22
# Strongly disagree (1)     18
# Name: 45 You feel gratification shopping on your favorite e-tailer, dtype: int64

# %%
sns.catplot(df_cust['45 You feel gratification shopping on your favorite e-tailer'],data=df_cust,kind='count',height=7,aspect=2)

# %% [markdown]
# #### 47.5 % people says they feel Happy by shopping on their favorite e-tailer where as 15% completely disagree this and 37% have diffrent reasons to shop online

# %%
df_cust['46 Shopping on the website helps you fulfill certain roles'].value_counts()
# Out:
# Agree (4)                88
# indifferent (3)          88
# Strongly agree (5)       38
# Strongly disagree (1)    33
# Dis-agree (2)            22
# Name: 46 Shopping on the website helps you fulfill certain roles, dtype: int64

# %%
sns.catplot(df_cust['46 Shopping on the website helps you fulfill certain roles'],data=df_cust,kind='count',height=7,aspect=2)

# %% [markdown]
# #### 46.5 % people says they feel Shopping on the website helps them fulfilling certain roles where as 20.4 % completely disagree this and 32.7% have diffrent reasons to shop online

# %%
df_cust['47 Getting value for money spent'].value_counts()
# Out:
# Agree (4)             149
# Strongly agree (5)     82
# indifferent (3)        38
# Name: 47 Getting value for money spent, dtype: int64

# %%
sns.catplot(df_cust['47 Getting value for money spent'],data=df_cust,kind='count',height=7,aspect=1)

# %% [markdown]
# #### 85.5 % people says they feel Shopping on the website gives value for moneys which will keep customers retained where as 14.4 % completely disagree this which

# %%
df_cust['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           '].value_counts()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    82
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in, Flipkart.com                                         32
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                29
# Amazon.in, Flipkart.com, Snapdeal.com                           27
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in                                                       16
# Amazon.in, Paytm.com                                            12
# Amazon.in, Flipkart.com, Paytm.com                               7
# Name: From the following, tick any (or all) of the online retailers you have shopped from;                                                                           , dtype: int64

# %%
sns.catplot(df_cust['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           '],data=df_cust,kind='count',height=7,aspect=4.5)

# %% [markdown]
# **1) we can observe almost 100% of people have shoped on Amazon.in
# 2)82% people shoped on  Flipkart.com
# 3)67.7% people shoped on  Snapdeal.com
# 4)55.7% people shoped on  Paytm.com
# 5)54% people shoped on  Myntra.com
# "Amazon.in" has gained heighest(100%) Popularity amoungest customers and  Myntra.com has lowest(54%) amoungest rest of the 4 sites.**

# %%
y=df_cust['Easy to use website or application'].value_counts()
# Out:
# 29

# %%
import itertools 
for i,j in  zip(fill ,index):
    print(i,j)
    titanic_df['Age'][j]=i
    print(titanic_df['Age'][i])

# %%
# count=0

# x=df_cust['Easy to use website or application'].unique()
# print(x)
# print("  ")
# for i in x:
#     count=count+1
#     print(i)
#     print(y[count])
#     list= i.split(",")
#     print(len(list))
#     for j in range(len(list)):
#        # print(j)
# Out:
#   File "<ipython-input-101-0d32b4484f2c>", line 13
#     # print(j)
#               ^
# SyntaxError: unexpected EOF while parsing

# %%
df_cust['Easy to use website or application'].value_counts()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    64
# Amazon.in, Flipkart.com                                         44
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in                                                       29
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                22
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Flipkart.com, Myntra.com                             19
# Paytm.com                                                       12
# Flipkart.com                                                     8
# Amazon.in, Paytm.com                                             7
# Name: Easy to use website or application, dtype: int64

# %%
sns.catplot(df_cust['Easy to use website or application'],data=df_cust,kind='count',height=7,aspect=4)

# %% [markdown]
# **1) we can observe almost 92.56% of people belive Amazon.in is easy to access .
# 2)74.72%people belive that  Flipkart.com is easy to access
# 3)48.32%people belive that  Snapdeal.com  is easy to access
# 4)46.46%people belive that Paytm.com  is easy to acces
# 5)54.64%people belive that  Myntra.com is easy to acces
# "Amazon.in" is highly user friendly(92.56%) as per customers and  Paytm.com is lowest (46.46%) easy to access website amoungest rest of the 4 sites.**

# %%
cust=df_cust['Visual appealing web-page layout'].value_counts()
cust
# Out:
# Amazon.in, Flipkart.com                                         87
# Amazon.in                                                       44
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    36
# Amazon.in, Paytm.com, Myntra.com                                20
# Myntra.com                                                      15
# Flipkart.com, Myntra.com                                        15
# Amazon.in, Myntra.com                                           15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Flipkart.com                                                    12
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                11
# Name: Visual appealing web-page layout, dtype: int64

# %%
sns.catplot(df_cust['Visual appealing web-page layout'],data=df_cust,kind='count',height=7,aspect=4.5)

# %% [markdown]
# **1) we can observe almost 84.38% of people think Amazon.in has visually appealing layout .
# 2)60.59% people thinks  Flipkart.com has visuaaly appealing layout .
# 3)22.67% people thinks  Snapdeal.com has visuaaly appealing layout .
# 4)24.9% people thinks  Paytm.com has visuaaly appealing layout .
# 5)37.17% people thinks  Myntra.com has visuaaly appealing layout .
# As per customers Amazon.in's Layout is highly visually appealing layout and Paytm.com's is lowest appealing in amoungest all 5.**

# %%
df_cust['Wild variety of product on offer'].value_counts()
# Out:
# Amazon.in, Flipkart.com                              130
# Amazon.in                                             43
# Amazon.in, Myntra.com                                 20
# Myntra.com                                            15
# Flipkart.com, Myntra.com                              15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com     14
# Amazon.in, Flipkart.com, Paytm.com                    13
# Flipkart.com                                          12
# Paytm.com                                              7
# Name: Wild variety of product on offer, dtype: int64

# %%
sns.catplot(df_cust['Wild variety of product on offer'],data=df_cust,kind='count',height=7,aspect=5.5)

# %% [markdown]
# **1)As per 81.78% customers think that Amazon.in has Wild variety of product on offer
# 2)As per 68.4% customers think that Flipkart.com has Wild variety of product on offer
# 3)As per 5.20% customers think that Snapdeal.com  has Wild variety of product on offer
# 4)As per 7.43% customers think that Paytm.com has Wild variety of product on offer
# 5)As per 18.21% customers think that Myntra.com  has Wild variety of product on offer**

# %%
df_cust['Complete, relevant description information of products'].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         100
# Amazon.in                                                        43
# Amazon.in, Flipkart.com, Paytm.com                               24
# Amazon.in, Paytm.com, Myntra.com                                 20
# Amazon.in, Flipkart.com, Myntra.com                              15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com     15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                14
# Snapdeal.com                                                     12
# Flipkart.com, Snapdeal.com                                       11
# Flipkart.com                                                      8
# Amazon.in, Flipkart.com, Snapdeal.com                             7
# Name: Complete, relevant description information of products, dtype: int64

# %%
sns.catplot(df_cust['Complete, relevant description information of products'],data=df_cust,kind='count',height=7,aspect=5.5)

# %% [markdown]
# **1)As per 88.4% customers think that Amazon.in has Complete, relevant description information of products
# 2)As per 72.11% customers think that Flipkart.com has Complete, relevant description information of products
# 3)As per 21.9% customers think that Snapdeal.com has Complete, relevant description information of products
# 4)As per 21.9% customers think that Paytm.com  has Complete, relevant description information of products
# 5)As per 23.79% customers think that Myntra.com  has Complete, relevant description information of products**

# %%
df_cust['Fast loading website speed of website and application'].value_counts()
# Out:
# Amazon.in                                                       51
# Amazon.in, Paytm.com                                            44
# Amazon.in, Flipkart.com, Myntra.com                             30
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    30
# Amazon.in, Flipkart.com                                         30
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com, Paytm.com                              25
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Snapdeal.com                                                    12
# Flipkart.com                                                     8
# Name: Fast loading website speed of website and application, dtype: int64

# %%
sns.catplot(df_cust['Fast loading website speed of website and application'],data=df_cust,kind='count',height=7,aspect=5.5)

# %% [markdown]
# **1)As per 92.56% customers think that Amazon.in is Fast loading website speed of website and application
# 2)As per 60.22% customers think that Flipkart.com is Fast loading website speed of website and application
# 3)As per 30.11% customers think that Snapdeal.com is Fast loading website speed of website and application
# 4)As per 36.8% customers think that Paytm.com  is Fast loading website speed of website and application
# 5)As per 27.5% customers think that Myntra.com is Fast loading website speed of website and application**

# %%
df_cust['Quickness to complete purchase'].value_counts()
# Out:
# Amazon.in                                            61
# Amazon.in, Flipkart.com                              50
# Amazon.in, Flipkart.com, Paytm.com                   36
# Amazon.in, Paytm.com, Myntra.com                     35
# Amazon.in, Flipkart.com, Snapdeal.com                18
# Flipkart.com                                         15
# Myntra.com                                           15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com    14
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com     13
# Paytm.com                                            12
# Name: Reliability of the website or application, dtype: int64

# %%
sns.catplot(df_cust['Quickness to complete purchase'],data=df_cust,kind='count',height=7,aspect=5.5)

# %% [markdown]
# **1)As per 84.38% customers think that Amazon.in has Quick response to complete purchase
# 2)As per 54.27% customers think that Flipkart.com has Quick response to complete purchase
# 3)As per 16.72% customers think that Snapdeal.com has Quick response to complete purchase
# 4)As per 35.68% customers think that Paytm.com  has Quick response to complete purchase
# 5)As per 23.79% customers think that Myntra.com Quick response to complete purchase**

# %%
df_cust['Availability of several payment options'].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         65
# Amazon.in, Flipkart.com, Myntra.com                             40
# Amazon.in, Flipkart.com, Patym.com, Myntra.com, Snapdeal.com    39
# Amazon.in                                                       23
# Patym.com, Myntra.com                                           20
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               19
# Amazon.in, Flipkart.com, Snapdeal.com                           18
# Flipkart.com, Myntra.com, Snapdeal.com                          14
# Patym.com                                                       12
# Amazon.in, Patym.com                                            11
# Flipkart.com                                                     8
# Name: Availability of several payment options, dtype: int64

# %%
sns.catplot(df_cust['Availability of several payment options'],data=df_cust,kind='count',height=7,aspect=5.5)

# %% [markdown]
# **1)As per 79.9% customers think that Amazon.in has Availability of several payment options
# 2)As per 42% customers think that Flipkart.com has Availability of several payment options
# 3)As per 33.45% customers think that Snapdeal.com has Availability of several payment options
# 4)As per 30.48% customers think that Paytm.com  has Availability of several payment options
# 5)As per 49% customers think that Myntra.com  has Availability of several payment options**

# %%
df_cust['Speedy order delivery '].value_counts()
# Out:
# Amazon.in                                 107
# Amazon.in, Flipkart.com                    82
# Amazon.in, Flipkart.com, Snapdeal.com      36
# Amazon.in, Flipkart.com, Myntra.com        15
# Flipkart.com                               15
# Flipkart.com, Myntra.com, Snapdeal.com     14
# Name: Speedy order delivery , dtype: int64

# %%
sns.catplot(df_cust['Speedy order delivery '],data=df_cust,kind='count',height=7,aspect=5.5)

# %%
**1)As per 89.2% customers think that Amazon.in has Speedy order delivery
2)As per 60.22% customers think that Flipkart.com has Speedy order delivery
3)As per 18.58% customers think that Snapdeal.com has Speedy order delivery  
4)As per 0% customers think that Paytm.com  has Complete, Speedy order delivery
5)As per 10.78% customers think that Myntra.com  has Speedy order delivery**

# %%
df_cust['Privacy of customers’ information'].value_counts()
# Out:
# Amazon.in                                                       71
# Amazon.in, Flipkart.com                                         54
# Amazon.in, Flipkart.com, Myntra.com                             25
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    24
# Paytm.com                                                       18
# Amazon.in, Paytm.com                                            15
# Myntra.com                                                      15
# Flipkart.com                                                    15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Amazon.in, Flipkart.com, Snapdeal.com                            7
# Name: Privacy of customers’ information, dtype: int64

# %%
sns.catplot(df_cust['Privacy of customers’ information'],data=df_cust,kind='count',height=7,aspect=5.5)

# %% [markdown]
# **1)As per 82.15% customers think that Amazon.in keeps 'Privacy of customers’ information'
# 2)As per 55.76% customers think that Flipkart.com keeps 'Privacy of customers’ information'
# 3)As per 16.73% customers think that Snapdeal.com keeps 'Privacy of customers’ information'
# 4)As per 18.58% customers think that Paytm.com  keeps 'Privacy of customers’ information'
# 5)As per 28.99% customers think that Myntra.com  keeps 'Privacy of customers’ information'**

# %%
df_cust['Security of customer financial information'].value_counts()
# Out:
# Amazon.in                                                       51
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    42
# Flipkart.com                                                    33
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com                                         24
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Snapdeal.com                                         19
# Myntra.com                                                      15
# Paytm.com                                                       15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Security of customer financial information, dtype: int64

# %%
sns.catplot(df_cust['Security of customer financial information'],data=df_cust,kind='count',height=7,aspect=5.5)

# %% [markdown]
# **1)As per 76.57% customers think that Amazon.in keeps Security of customer financial information
# 2)As per 55.39% customers think that Flipkart.com keeps Security of customer financial information
# 3)As per 32.7% customers think that Snapdeal.com keeps Security of customer financial information
# 4)As per 32.7% customers think that Paytm.com  keeps Security of customer financial information
# 5)As per 33.8% customers think that Myntra.com keeps Security of customer financial information**

# %%
df_cust['Perceived Trustworthiness'].value_counts()
# Out:
# Amazon.in                                                       76
# Amazon.in, Flipkart.com, Snapdeal.com                           36
# Amazon.in, Myntra.com                                           35
# Amazon.in, Flipkart.com                                         31
# Flipkart.com                                                    27
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               25
# Myntra.com                                                      15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    13
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Perceived Trustworthiness, dtype: int64

# %%
sns.catplot(df_cust['Perceived Trustworthiness'],data=df_cust,kind='count',height=7,aspect=5)

# %% [markdown]
# #### According above statistics we can say Amozon maintains very good Security of customer financial information .
# #### an dthats why it manage to retain customer more than anynother online platform .
# #### and thats why it Perceived  heighest Trustworthiness .

# %%
df_cust['Presence of online assistance through multi-channel'].value_counts()
# Out:
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal    61
# Amazon.in                                        60
# Amazon.in, Flipkart.com                          39
# Amazon.in, Snapdeal                              26
# Myntra.com                                       20
# Amazon.in, Flipkart.com, Myntra.com              15
# Amazon.in, Myntra.com                            15
# Amazon.in, Flipkart.com, Paytm.com               13
# Paytm.com                                        12
# Flipkart.com                                      8
# Name: Presence of online assistance through multi-channel, dtype: int64

# %%
sns.catplot(df_cust['Presence of online assistance through multi-channel'],data=df_cust,kind='count',height=7,aspect=5)

# %%
df_cust['Longer time to get logged in (promotion, sales period)'].value_counts()
# Out:
# Amazon.in                                57
# Paytm.com                                38
# Amazon.in, Flipkart.com                  38
# Myntra.com                               35
# Amazon.in, Flipkart.com, Snapdeal.com    29
# Snapdeal.com                             25
# Flipkart.com, Paytm.com                  15
# Flipkart.com, Paytm.com, Snapdeal.com    13
# Amazon.in, Paytm.com                     11
# Flipkart.com                              8
# Name: Longer time to get logged in (promotion, sales period), dtype: int64

# %%
sns.catplot(df_cust['Longer time to get logged in (promotion, sales period)'],data=df_cust,kind='count',height=7,aspect=5)

# %%
df_cust['Longer time in displaying graphics and photos (promotion, sales period)'].value_counts()
# Out:
# Amazon.in, Flipkart.com                60
# Amazon.in                              39
# Myntra.com                             35
# Snapdeal.com                           34
# Myntra.com, Snapdeal.com               25
# Flipkart.com, Snapdeal.com             19
# Paytm.com                              15
# Flipkart.com                           15
# Amazon.in, Myntra.com, Snapdeal.com    14
# Amazon.in, Paytm.com                   13
# Name: Longer time in displaying graphics and photos (promotion, sales period), dtype: int64

# %%
sns.catplot(df_cust['Longer time in displaying graphics and photos (promotion, sales period)'],data=df_cust,kind='count',height=7,aspect=5)

# %%
df_cust['Late declaration of price (promotion, sales period)'].value_counts()
# Out:
# Myntra.com                 75
# Paytm.com                  52
# snapdeal.com               41
# Amazon.in                  38
# Flipkart.com               38
# Amazon.in, Paytm.com       13
# Paytm.com, snapdeal.com     7
# Amazon.in, Flipkart.com     5
# Name: Late declaration of price (promotion, sales period), dtype: int64

# %%
sns.catplot(df_cust['Late declaration of price (promotion, sales period)'],data=df_cust,kind='count',height=7,aspect=5)

# %%
df_cust['Longer page loading time (promotion, sales period)'].value_counts()
# Out:
# Myntra.com                          61
# Paytm.com                           59
# Flipkart.com                        32
# Snapdeal.com                        23
# Amazon.in, Flipkart.com             18
# Amazon.in                           16
# Paytm.com, Snapdeal.com             15
# Amazon.in, Snapdeal.com             14
# Amazon.in, Paytm.com                13
# Flipkart.com, Snapdeal.com          11
# Amazon.in, Paytm.com, Myntra.com     7
# Name: Longer page loading time (promotion, sales period), dtype: int64

# %%
sns.catplot(df_cust['Longer page loading time (promotion, sales period)'],data=df_cust,kind='count',height=7,aspect=5)

# %%
df_cust['Limited mode of payment on most products (promotion, sales period)'].value_counts()
# Out:
# Snapdeal.com                87
# Amazon.in                   62
# Flipkart.com                31
# Amazon.in, Flipkart.com     29
# Paytm.com                   25
# Paytm.com, Snapdeal.com     15
# Amazon.in, Paytm.com        13
# Myntra.com, Snapdeal.com     7
# Name: Limited mode of payment on most products (promotion, sales period), dtype: int64

# %%
sns.catplot(df_cust['Limited mode of payment on most products (promotion, sales period)'],data=df_cust,kind='count',height=7,aspect=5)

# %%
df_cust['Longer delivery period'].value_counts()
# Out:
# Paytm.com                  72
# Snapdeal.com               64
# Flipkart.com               44
# Amazon.in                  37
# Myntra.com                 26
# Paytm.com, Snapdeal.com    26
# Name: Longer delivery period, dtype: int64

# %%
sns.catplot(df_cust['Longer delivery period'],data=df_cust,kind='count',height=7,aspect=5)

# %%
df_cust['Change in website/Application design'].value_counts()
# Out:
# Amazon.in                   96
# Paytm.com                   63
# Amazon.in, Flipkart.com     45
# Myntra.com                  30
# Flipkart.com                20
# Snapdeal.com                 8
# Flipkart.com, Myntra.com     7
# Name: Change in website/Application design, dtype: int64

# %%
sns.catplot(df_cust['Change in website/Application design'],data=df_cust,kind='count',height=7,aspect=5)

# %%
df_cust['Frequent disruption when moving from one page to another'].value_counts()
# Out:
# Amazon.in                     53
# Myntra.com                    52
# Snapdeal.com                  49
# Paytm.com                     39
# Flipkart.com                  26
# Amazon.in, Flipkart.com       25
# Myntra.com, Snapdeal.com      14
# Flipkart.com, Snapdeal.com    11
# Name: Frequent disruption when moving from one page to another, dtype: int64

# %%
sns.catplot(df_cust['Frequent disruption when moving from one page to another'],data=df_cust,kind='count',height=7,aspect=5)

# %%
df_cust['Website is as efficient as before'].value_counts()
# Out:
# Amazon.in                             94
# Flipkart.com                          47
# Amazon.in, Flipkart.com               45
# Amazon.in, Flipkart.com, Paytm.com    25
# Amazon.in, Paytm.com                  18
# Paytm.com                             15
# Myntra.com, Snapdeal.com              14
# Snapdeal.com                          11
# Name: Website is as efficient as before, dtype: int64

# %%
sns.catplot(df_cust['Website is as efficient as before'],data=df_cust,kind='count',height=7,aspect=5)

# %%
df_cust['Which of the Indian online retailer would you recommend to a friend?'].value_counts()
# Out:
# Amazon.in                                            79
# Amazon.in, Flipkart.com                              62
# Flipkart.com                                         39
# Amazon.in, Myntra.com                                30
# Amazon.in, Paytm.com, Myntra.com                     20
# Amazon.in, Flipkart.com, Myntra.com                  15
# Amazon.in, Paytm.com                                 13
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com    11
# Name: Which of the Indian online retailer would you recommend to a friend?, dtype: int64

# %%
sns.catplot(df_cust['Which of the Indian online retailer would you recommend to a friend?'],data=df_cust,kind='count',height=7,aspect=5)
